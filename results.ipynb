# %%
from inclearn import results_utils

# %% [markdown]
# # iCIFAR100, 10-split

# %%
results_utils.plot(
    [
        {
            "path": "results/papers/paper_icarl_10.json",
            "label": "[paper] iCaRL",
        },
        {
            "path": "results/papers/paper_lwf_10.json",
            "label": "[paper] LwF   "
        },
        {
            "path": "results/papers/paper_e2e_10.json",
            "label": "[paper] E2E   "
        },

        {
            "path": "results/icarl_tue",
            "label": "[me]     iCaRL",
            "average_incremental": True, "skip_first": False
        },
        {
            "path": "results/e2e_tue",
            "label": "[me]     E2E   ",
            "average_incremental": True, "skip_first": False
        },
    ],
    increment=10,
    total=100,
    title="iCIFAR100, 10-split, average of 20 runs (seed 1->20)",
    path_to_save="figures/icifar100_10split.png"
)
